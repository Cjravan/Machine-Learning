# %%
import pandas as ps
import numpy as pn
import zipfile
import matplotlib.pyplot as mt
import seaborn as sns
% matplotlib inline
from sklearn.model_selection import train_test_split
# Out:
# UsageError: Line magic function `%` not found.

# %%
fd=ps.read_csv("C:/Users/Harshit/Downloads/train.csv")
fd
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
fd2=ps.read_csv("C:/Users/Harshit/Downloads/test.csv")
fd2
# Out:
#        Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0         53      54       6       5      48      49       16  Test/00000.png
# 1         42      45       5       5      36      40        1  Test/00001.png
# 2         48      52       6       6      43      47       38  Test/00002.png
# 3         27      29       5       5      22      24       33  Test/00003.png
# 4         60      57       5       5      55      52       11  Test/00004.png
# ...      ...     ...     ...     ...     ...     ...      ...             ...
# 12625     42      41       5       6      37      36       12  Test/12625.png
# 12626     50      51       6       5      45      46       33  Test/12626.png
# 12627     29      29       6       6      24      24        6  Test/12627.png
# 12628     48      49       5       6      43      44        7  Test/12628.png
# 12629     32      31       6       5      27      26       10  Test/12629.png
#
# [12630 rows x 8 columns]

# %%
fd.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
fd.shape
# Out:
# (1460, 81)

# %%
fd.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
fd.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
fd.isnull().sum()/len(fd)*100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
fd.select_dtypes(include="object")
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %%
fd.select_dtypes(include="float")
# Out:
#       LotFrontage  MasVnrArea  GarageYrBlt
# 0            65.0       196.0       2003.0
# 1            80.0         0.0       1976.0
# 2            68.0       162.0       2001.0
# 3            60.0         0.0       1998.0
# 4            84.0       350.0       2000.0
# ...           ...         ...          ...
# 1455         62.0         0.0       1999.0
# 1456         85.0       119.0       1978.0
# 1457         66.0         0.0       1941.0
# 1458         68.0         0.0       1950.0
# 1459         75.0         0.0       1965.0
#
# [1460 rows x 3 columns]

# %%
fd.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# here we are dropping object columns
fd1=fd.select_dtypes(exclude="object")
fd1
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  \
# ...

# %%
fd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 38 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int64
#  7   YearRemodAdd   1460 non-null   int64
#  8   MasVnrArea     1452 non-null   float64
#  9   BsmtFinSF1     1460 non-null   int64
#  10  BsmtFinSF2     1460 non-null   int64
#  11  BsmtUnfSF      1460 non-null   int64
#  12  TotalBsmtSF    1460 non-null   int64
#  13  1stFlrSF       1460 non-null   int64
#  14  2ndFlrSF       1460 non-null   int64
#  15  LowQualFinSF   1460 non-null   int64
#  16  GrLivArea      1460 non-null   int64
#  17  BsmtFullBath   1460 non-null   int64
# ...

# %%
fd1.dropna(subset="LotFrontage",how="any",inplace=True)

# %%
fd1.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# LotFrontage       0
# LotArea           0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# MasVnrArea        6
# BsmtFinSF1        0
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# BsmtFullBath      0
# BsmtHalfBath      0
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# TotRmsAbvGrd      0
# Fireplaces        0
# GarageYrBlt      74
# GarageCars        0
# GarageArea        0
# WoodDeckSF        0
# OpenPorchSF       0
# EnclosedPorch     0
# 3SsnPorch         0
# ScreenPorch       0
# PoolArea          0
# MiscVal           0
# MoSold            0
# YrSold            0
# SalePrice         0
# dtype: int64

# %%
fd1.dropna(subset="GarageYrBlt",how="any",inplace=True)

# %%
fd1.dropna(subset="MasVnrArea",how="any",inplace=True)

# %%
sns.histplot(data=fd1,x="SalePrice",bins=101)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
fd1.shape
# Out:
# (1121, 38)

# %%
fd1.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  WoodDeckSF  OpenPorchSF  \
# 0          2003       196.0         706  ...           0           61
# 1          1976         0.0         978  ...         298            0
# 2          2002       162.0         486  ...           0           42
# 3          1970         0.0         216  ...           0           35
# 4          2000       350.0         655  ...         192           84
#
#    EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# ...

# %%
sns.heatmap(fd1.corr())
# Out:
# <Axes: >

# %%
sns.histplot(data=fd1,x="LotArea",bins=101)
# Out:
# <Axes: xlabel='LotArea', ylabel='Count'>

# %%
fd1.columns
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
fd1 = ps.DataFrame(fd1)

# %%
fd1.drop(['KitchenAbvGr','BedroomAbvGr',
                        'GarageYrBlt','BsmtFinSF1','BsmtFinSF2','BsmtHalfBath',
                       'MasVnrArea','HalfBath','FullBath','GrLivArea','LowQualFinSF',
                       'BsmtFullBath','WoodDeckSF','OpenPorchSF','MiscVal','EnclosedPorch',
                       '3SsnPorch','ScreenPorch','LotFrontage','MoSold','PoolArea','Id','TotRmsAbvGrd']
                       , axis = 1, inplace = True)

# %%
fd1.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  Fireplaces  GarageCars  \
# 0        150          856       856       854           0           2
# 1        284         1262      1262         0           1           2
# 2        434          920       920       866           1           2
# 3        540          756       961       756           1           3
# 4        490         1145      1145      1053           1           3
#
#    GarageArea  YrSold  SalePrice
# 0         548    2008     208500
# ...

# %%
fd1.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
fd1.shape
# Out:
# (1121, 15)

# %%
a=['KitchenAbvGr','BedroomAbvGr',
                        'GarageYrBlt','BsmtFinSF1','BsmtFinSF2','BsmtHalfBath',
                       'MasVnrArea','HalfBath','FullBath','GrLivArea','LowQualFinSF',
                       'BsmtFullBath','WoodDeckSF','OpenPorchSF','MiscVal','EnclosedPorch',
                       '3SsnPorch','ScreenPorch','LotFrontage','MoSold','PoolArea','Id','TotRmsAbvGrd']

# %%
len(a)
# Out:
# 23

# %%
cv=fd1.corr().abs()
print(cv)
# Out:
#               MSSubClass   LotArea  OverallQual  OverallCond  YearBuilt  \
# MSSubClass      1.000000  0.198096     0.029522     0.087859   0.025800
# LotArea         0.198096  1.000000     0.167525     0.034348   0.029205
# OverallQual     0.029522  0.167525     1.000000     0.163157   0.589385
# OverallCond     0.087859  0.034348     0.163157     1.000000   0.426462
# YearBuilt       0.025800  0.029205     0.589385     0.426462   1.000000
# YearRemodAdd    0.006645  0.026848     0.570757     0.039402   0.623171
# BsmtUnfSF       0.145582  0.011288     0.322663     0.148630   0.177545
# TotalBsmtSF     0.247781  0.302554     0.563960     0.192762   0.409134
# 1stFlrSF        0.252249  0.329679     0.514453     0.164251   0.308875
# 2ndFlrSF        0.319328  0.074612     0.273197     0.005985   0.011621
# Fireplaces      0.031122  0.255755     0.415294     0.022290   0.133077
# GarageCars      0.027411  0.172428     0.593803     0.267859   0.532563
# ...

# %%
fd1.shape
# Out:
# (1121, 15)

# %%
fd1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1121 entries, 0 to 1459
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MSSubClass    1121 non-null   int64
#  1   LotArea       1121 non-null   int64
#  2   OverallQual   1121 non-null   int64
#  3   OverallCond   1121 non-null   int64
#  4   YearBuilt     1121 non-null   int64
#  5   YearRemodAdd  1121 non-null   int64
#  6   BsmtUnfSF     1121 non-null   int64
#  7   TotalBsmtSF   1121 non-null   int64
#  8   1stFlrSF      1121 non-null   int64
#  9   2ndFlrSF      1121 non-null   int64
#  10  Fireplaces    1121 non-null   int64
#  11  GarageCars    1121 non-null   int64
#  12  GarageArea    1121 non-null   int64
#  13  YrSold        1121 non-null   int64
#  14  SalePrice     1121 non-null   int64
# dtypes: int64(15)
# memory usage: 140.1 KB

# %%
sns.catplot(data=fd1,x="SalePrice",y="YearBuilt",kind="boxen")
# Out:
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=fd1,x="SalePrice",y="2ndFlrSF",kind="violin")
# Out:
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# on the basis of year what is the price of property is.
sns.catplot(data=fd1,x="YrSold",y="SalePrice",kind="strip")
# Out:
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=fd1,x="YrSold",y="SalePrice",hue="OverallCond",kind="strip")
# Out:
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fd1.head()
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  Fireplaces  GarageCars  \
# 0        150          856       856       854           0           2
# 1        284         1262      1262         0           1           2
# 2        434          920       920       866           1           2
# 3        540          756       961       756           1           3
# 4        490         1145      1145      1053           1           3
#
#    GarageArea  YrSold  SalePrice
# 0         548    2008     208500
# ...

# %%
#checking Outliers
mt.figure(figsize=(10,7))
sns.boxplot(fd1['SalePrice'],color='b')
mt.show()

# %%
sns.swarmplot(data=fd1, x="GarageCars", y="SalePrice",hue="Fireplaces", size=3)
# Out:
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 22.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 24.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='GarageCars', ylabel='SalePrice'>
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 29.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.catplot(data=fd1, x="GarageCars", y="SalePrice", kind="violin", color=".9", inner=None)
sns.swarmplot(data=fd1, x="GarageCars", y="SalePrice", size=3)
# Out:
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 26.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 28.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='GarageCars', ylabel='SalePrice'>
# C:\Users\Harshit\anaconda3\envs\tensorflow_new\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=fd1.drop("SalePrice",axis=1)
y=fd1["SalePrice"]

# %%
fd1.columns
# Out:
# Index(['MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt',
#        'YearRemodAdd', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'Fireplaces', 'GarageCars', 'GarageArea', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression() #instantiate
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# -304566.70389585814

# %%
coeff_hpa1 = ps.DataFrame(lr.coef_,X.columns,columns=['Coefficient'])
coeff_hpa1
# Out:
#                Coefficient
# MSSubClass     -108.238706
# LotArea           1.082953
# OverallQual   17235.657976
# OverallCond    4284.669140
# YearBuilt       313.530616
# YearRemodAdd    298.473786
# BsmtUnfSF       -24.921834
# TotalBsmtSF      49.508389
# 1stFlrSF         55.736355
# 2ndFlrSF         60.768885
# Fireplaces     4511.913274
# GarageCars     -787.694784
# GarageArea       47.014716
# YrSold         -501.322911

# %%
Y_predict = lr.predict(X_test)

# %%
mt.scatter(y_test,Y_predict)

# %%
sns.distplot((y_test-Y_predict),bins=50)
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_11596\805779602.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot((y_test-Y_predict),bins=50)
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, Y_predict))
print('MSE:', metrics.mean_squared_error(y_test, Y_predict))
print('RMSE:', pn.sqrt(metrics.mean_squared_error(y_test, Y_predict)))
# Out:
# MAE: 24469.052130647273
# MSE: 2618948226.261854
# RMSE: 51175.66048681594

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables=x

vif=ps.DataFrame()

vif["VIF"]= [variance_inflation_factor(variables,i) for i in range (variables.shape[1])]

vif["Features"]=x.columns

# %%
vif
# Out:
#          VIF     Features
# 0  21.977947  OverallQual
# 1  23.459523  TotalBsmtSF
# 2  31.996637     1stFlrSF
# 3  34.441402   GarageCars
# 4  29.293174   GarageArea

# %%
X_train.shape
# Out:
# (672, 14)

# %%
y_train.shape
# Out:
# (672,)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_train)
# Out:
# Linear Regression r2_score for training is 0.8417314316384087

# %%
Y_train_predict = model.predict(X_train)

train_score = r2_score(y_train, Y_train_predict)
print('Linear Regression r2_score for training set is', train_score)

Y_test_predict = model.predict(X_test)

test_score = r2_score(y_test, Y_test_predict)
print('Linear Regression r2_score for test set is', test_score)
# Out:
# Linear Regression r2_score for training set is 0.8417314316384087
# Linear Regression r2_score for test set is 0.6877780425752628
